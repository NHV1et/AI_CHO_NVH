# %%
import streamlit as st
from llama_index.llms.ollama import Ollama
from llama_index.core import Settings
from llama_index.core import VectorStoreIndex, ServiceContext, SimpleDirectoryReader
from llama_index.core.llms import ChatMessage, MessageRole
from llama_index.core.node_parser import SimpleNodeParser

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File d:\AI_CHO_NVH\venv\Lib\site-packages\transformers\utils\import_utils.py:2207, in _LazyModule.__getattr__(self, name)
#    2206 try:
# -> 2207     module = self._get_module(self._class_to_module[name])
#    2208     value = getattr(module, name)
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\transformers\utils\import_utils.py:2441, in _LazyModule._get_module(self, module_name)
#    2440 except Exception as e:
# -> 2441     raise e
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\transformers\utils\import_utils.py:2439, in _LazyModule._get_module(self, module_name)
#    2438 try:
# -> 2439     return importlib.import_module("." + module_name, self.__name__)
#    2440 except Exception as e:
#
# File D:\Python\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1334, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:950, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1026, in _LoaderBasics.exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\transformers\modeling_utils.py:69
#      68 from .integrations.flash_attention import flash_attention_forward
# ---> 69 from .integrations.flash_paged import paged_attention_forward
#      70 from .integrations.flex_attention import flex_attention_forward
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\transformers\integrations\flash_paged.py:7
#       4 from ..modeling_flash_attention_utils import lazy_import_paged_flash_attention
# ----> 7 @torch.compiler.disable
#       8 def paged_attention_forward(
#       9     module: torch.nn.Module,
#      10     q: torch.Tensor,
#      11     k: torch.Tensor,
#      12     v: torch.Tensor,
#      13     attention_mask: torch.Tensor | None,  # Unused in flash
#      14     cache: PagedAttentionCache,
#      15     cu_seq_lens_q: torch.Tensor,
#      16     cu_seq_lens_k: torch.Tensor | dict[str, torch.Tensor],
#      17     max_seqlen_q: int,
#      18     max_seqlen_k: int | dict[str, int],
#      19     block_table: torch.Tensor | None,
#      20     **kwargs,
#      21 ) -> tuple[torch.Tensor, None]:
#      22     """Performs the forward pass of attention with paged key-value cache. This function handles the cache updates and
#      23     performs the attention computation. For decode-only batches (when block_table is provided), uses
#      24     `flash_attn_with_kvcache` for fused attention + cache update. Otherwise uses `flash_attn_varlen_func`.
#    (...)     42             max_blocks_per_seq blocks, the block table is padded with -1s to indicate that the block is not allocated.
#      43     """
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\torch\compiler\__init__.py:259, in disable(fn, recursive, reason)
#     250 """
#     251 This function provides a decorator to disable compilation on a function.
#     252 It also provides the option of recursively disabling called functions.
#    (...)    257     reason (optional): A string value indicating the reason for disabling the function.
#     258 """
# --> 259 import torch._dynamo
#     261 return torch._dynamo.disable(fn, recursive, reason=reason)
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\torch\_dynamo\__init__.py:13
#      11 import torch
# ---> 13 from . import (
#      14     aot_compile,
#      15     config,
#      16     convert_frame,
#      17     eval_frame,
#      18     functional_export,
#      19     resume_execution,
#      20 )
#      21 from .backends.registry import list_backends, lookup_backend, register_backend
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\torch\_dynamo\aot_compile.py:15
#      14 import torch.fx
# ---> 15 from torch._dynamo.convert_frame import GraphRuntimeEnv
#      16 from torch._dynamo.graph_utils import _graph_device_type
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\torch\_dynamo\convert_frame.py:62
#      61 from torch._dynamo.distributed import get_compile_pg
# ---> 62 from torch._dynamo.symbolic_convert import TensorifyState
#      63 from torch._guards import compile_context, CompileContext, CompileId, tracing
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\torch\_dynamo\symbolic_convert.py:60
#      58 from torch.utils._functools import cache_method
# ---> 60 from . import (
#      61     config,
#      62     exc,
#      63     graph_break_hints,
#      64     logging as torchdynamo_logging,
#      65     trace_rules,
#      66     variables,
#      67 )
#      68 from .bytecode_analysis import (
#      69     get_indexof,
#      70     JUMP_OPNAMES,
#      71     livevars_analysis,
#      72     propagate_line_nums,
#      73 )
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\torch\_dynamo\trace_rules.py:59
#      52 from .utils import (
#      53     getfile,
#      54     hashable,
#    (...)     57     unwrap_if_wrapper,
#      58 )
# ---> 59 from .variables import (
#      60     BuiltinVariable,
#      61     FunctionalCallVariable,
#      62     FunctorchHigherOrderVariable,
#      63     InspectSignatureVariable,
#      64     LocalGeneratorFunctionVariable,
#      65     LocalGeneratorObjectVariable,
#      66     NestedUserFunctionVariable,
#      67     PolyfilledFunctionVariable,
#      68     PyTreeGetNodeTypeFunctionVariable,
#      69     PyTreeTreeIsLeafFunctionVariable,
#      70     ReparametrizeModuleCallVariable,
#      71     SkipFunctionVariable,
#      72     SparseTensorCreationSkipVariable,
#      73     TorchInGraphFunctionVariable,
#      74     UserFunctionVariable,
#      75     UserMethodVariable,
#      76 )
#      77 from .variables.base import VariableTracker
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\torch\_dynamo\variables\__init__.py:19
#       1 """
#       2 This package implements variable tracking and symbolic execution capabilities for Dynamo,
#       3 which are essential for converting Python code into FX graphs. It provides a comprehensive
#    (...)     16 allows Dynamo to accurately trace and optimize Python code while preserving its semantics.
#      17 """
# ---> 19 from .base import VariableTracker
#      20 from .builtin import BuiltinVariable
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\torch\_dynamo\variables\base.py:929
#     928 instancecheck = type.__instancecheck__
# --> 929 from . import builder
#     930 from .lazy import LazyVariableTracker
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\torch\_dynamo\variables\builder.py:285
#     277 from .tensor import (
#     278     NumpyNdarrayVariable,
#     279     supported_const_comparison_op_values,
#    (...)    283     UnspecializedPythonVariable,
#     284 )
# --> 285 from .torch import (
#     286     DispatchKeySetVariable,
#     287     FuncTorchInterpreterVariable,
#     288     TorchCtxManagerClassVariable,
#     289     TorchInGraphFunctionVariable,
#     290 )
#     291 from .torch_function import (
#     292     TensorWithTFOverrideVariable,
#     293     torch_function_mode_stack_state_mgr,
#     294     TorchFunctionModeVariable,
#     295 )
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\torch\_dynamo\variables\torch.py:173
#     162 constant_fold_functions_need_guards = [
#     163     torch.accelerator.current_device_index,
#     164     torch.accelerator.current_accelerator,
#    (...)    168     torch.xpu.is_initialized,
#     169 ]
#     171 constant_fold_functions = [
#     172     torch._assert,
# --> 173     torch._utils._get_device_index,
#     174     torch._C._get_cublas_allow_tf32,
#     175     torch._C._is_any_autocast_enabled,
#     176     torch.accelerator.is_available,
#     177     torch.cuda.get_device_properties,
#     178     torch.cuda.is_available,
#     179     torch.distributed.is_available,
#     180     torch.get_autocast_dtype,
#     181     torch.get_autocast_gpu_dtype,
#     182     torch.get_default_dtype,
#     183     torch.is_autocast_cache_enabled,
#     184     torch.is_autocast_cpu_enabled,
#     185     torch.is_autocast_enabled,
#     186     torch.is_complex,
#     187     torch.is_floating_point,
#     188     torch.nn.functional._Reduction.get_enum,  # type: ignore[attr-defined]
#     189     torch.promote_types,
#     190     torch._C._get_privateuse1_backend_name,
#     191     torch.autograd._is_checkpoint_valid,
#     192     torch.xpu.get_device_properties,
#     193     torch.xpu.is_available,
#     194 ] + constant_fold_functions_need_guards
#     195 if torch.distributed.is_available():
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\torch\__init__.py:2881, in __getattr__(name)
#    2879     return importlib.import_module(f".{name}", __name__)
# -> 2881 raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#
# AttributeError: module 'torch' has no attribute '_utils'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from llama_index.embeddings.huggingface import HuggingFaceEmbedding
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\llama_index\embeddings\huggingface\__init__.py:1
# ----> 1 from llama_index.embeddings.huggingface.base import (
#       2     HuggingFaceEmbedding,
#       3     HuggingFaceInferenceAPIEmbedding,
#       4     HuggingFaceInferenceAPIEmbeddings,
#       5 )
#       7 __all__ = [
#       8     "HuggingFaceEmbedding",
#       9     "HuggingFaceInferenceAPIEmbedding",
#      10     "HuggingFaceInferenceAPIEmbeddings",
#      11 ]
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\llama_index\embeddings\huggingface\base.py:31
#      23 from llama_index.embeddings.huggingface.utils import (
#      24     DEFAULT_HUGGINGFACE_EMBEDDING_MODEL,
#      25     format_query,
#    (...)     28     get_text_instruct_for_model_name,
#      29 )
#      30 from llama_index.core.schema import ImageType
# ---> 31 from sentence_transformers import SentenceTransformer
#      32 from tenacity import retry, stop_after_attempt, wait_exponential
#      34 DEFAULT_HUGGINGFACE_LENGTH = 512
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\sentence_transformers\cross_encoder\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:21
#      19 from torch import nn
#      20 from tqdm.autonotebook import trange
# ---> 21 from transformers import (
#      22     AutoConfig,
#      23     AutoModelForSequenceClassification,
#      24     AutoTokenizer,
#      25     PretrainedConfig,
#      26     PreTrainedModel,
#      27     PreTrainedTokenizer,
#      28     is_torch_npu_available,
#      29 )
#      30 from transformers.utils import PushToHubMixin
#      31 from typing_extensions import deprecated
#
# File d:\AI_CHO_NVH\venv\Lib\site-packages\transformers\utils\import_utils.py:2295, in _LazyModule.__getattr__(self, name)
#    2291                     raise ModuleNotFoundError(
#    2292                         f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2293                     ) from e
#    2294         else:
# -> 2295             raise ModuleNotFoundError(
#    2296                 f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2297             ) from e
#    2299 elif name in self._modules:
#    2300     try:
#
# ModuleNotFoundError: Could not import module 'PreTrainedModel'. Are this object's requirements defined correctly?
